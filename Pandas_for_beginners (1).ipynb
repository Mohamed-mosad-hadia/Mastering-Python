# %% [markdown]
# #Pandas
#
# - A Pandas `Series` is like a column in a table , It is a one-dimensional array holding data of any type.
#
# - A Pandas `DataFrame` is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
#
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Series Pd

# %%
# create series array
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)

#convert sseries into numpy array
myvar.values
print(type(myvar.values))
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64
# <class 'numpy.ndarray'>

# %%
#custom  series array with label

a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)

#another type
b=pd.Series (data=[11,22,33,44,55],index=['a','b','c','d','e'])
print(b)
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# a    11
# b    22
# c    33
# d    44
# e    55
# dtype: int64

# %%
#series index access
print(myvar[0]) # access by position
print(myvar["y"]) # access by index
# Out:
# 1
# 7
# <ipython-input-84-69db8f26fe2b>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(myvar[0]) # access by position

# %%
# Create a dictionary to represent key-value pairs
#The keys of the dictionary become the labels.
data = {  'a': 10,
          'b': 20,
          'c': 30,
          'd': 40,
          'e': 50   }

# Create a Pandas Series from the dictionary
my_series = pd.Series(data)

# Print the Series
print(my_series)
my_series
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
# Accessing elements using slicing position
print(my_series[1:4])  # Access elements from index 1 up to (but not including) index 4
print(my_series[:3])   # Access elements from the beginning up to (but not including) index 3
print(my_series[2:])   # Access elements from index 2 to the end
print(my_series[:-2]) # Access elements from beginning to second last element
print(my_series[-3:])  # Access elements from third last element to end

# Accessing elements using slicing Indexing
print(my_series['a':'c'])  # Access elements from index 'a' up to (including) index 'c'
print(my_series[:'b'])     # Access elements from the beginning up to (including) index 'b'
print(my_series['d':])     # Access elements from index 'd' to the end
# Out:
# b    20
# c    30
# d    40
# dtype: int64
# a    10
# b    20
# c    30
# dtype: int64
# c    30
# d    40
# e    50
# dtype: int64
# a    10
# b    20
# c    30
# dtype: int64
# c    30
# d    40
# e    50
# dtype: int64
# a    10
# b    20
# c    30
# dtype: int64
# a    10
# b    20
# dtype: int64
# d    40
# e    50
# dtype: int64

# %% [markdown]
# #DataFrame

# %%
# key == name of columns
#values == values of rows

data = {
    'calories' : [400,450,500],
    'fat'      : [10,20,30]
}

df=pd.DataFrame (data )
print(df)
df
# Out:
#    calories  fat
# 0       400   10
# 1       450   20
# 2       500   30
#    calories  fat
# 0       400   10
# 1       450   20
# 2       500   30

# %%
# Create a large dictionary with sample data
population  = [100,200,300,400,500,600,900,1000]
area        = ['MANS', 'HAM', 'CAR','BMW','MER','LLM','GEN' ,'soso']

data = {
    'population': population,
    'area':area
}

# Create a DataFrame from the dictionary
big_df = pd.DataFrame(data)
big_df
# Out:
#    population  area
# 0         100  MANS
# 1         200   HAM
# 2         300   CAR
# 3         400   BMW
# 4         500   MER
# 5         600   LLM
# 6         900   GEN
# 7        1000  soso

# %%
big_df.columns
# Out:
# Index(['population', 'area'], dtype='object')

# %%
big_df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
big_df['population'] # output series
# Out:
# 0     100
# 1     200
# 2     300
# 3     400
# 4     500
# 5     600
# 6     900
# 7    1000
# Name: population, dtype: int64

# %%
print(big_df['population'][0])  # output value
print(big_df['population'][0:3])  # output value
# Out:
# 100
# 0    100
# 1    200
# 2    300
# Name: population, dtype: int64

# %% [markdown]
# # Indxing and selection
#
# - loc is label-based, which means that you have to specify rows and columns based on their row and column labels.
# - iloc is integer position-based, so you have to specify rows and columns by their integer position values (0-based integer position).
# -
#
# ```
# # iloc
# So, if my dataset is messed up and the index of 0 is present in the other, and I go and use iloc, it will fetch the first row in the data even if its index is 100.
#  يعني لو الداتا سيت بتاعتي متلغبطه و الاندكس بتاع 0 موجود في الاحري و روحت استخدمته هيجلبي اول سطر في الداتا حتي لو كانت الاندكس بتاعها 100 و طبعا بنتعامل بالارقام
# ```

# %%
#Locate Row at dataframe
# loc attribute to return one or more specified row(s)
print(big_df.loc[0])
print('**'*50)
print(big_df.loc[[0, 1]])
# Out:
# population     100
# area          MANS
# Name: 0, dtype: object
# ****************************************************************************************************
#    population  area
# 0         100  MANS
# 1         200   HAM

# %%
# Sample DataFrame
data = {'col1': [1, 2, 3, 4, 5], 'col2': [6, 7, 8, 9, 10]}
df = pd.DataFrame(data, index=['A', 'B', 'C', 'D', 'E'])

# Using .loc
print("Using .loc:")
print(df.loc['A'])  # Access row with label 'A'
print(df.loc[['A', 'C']]) # Access rows with labels 'A' and 'C'
print(df.loc['A', 'col1'])  # Access value at row 'A', column 'col1'
print(df.loc['A':'C', 'col1':'col2'])  # Access rows 'A' to 'C', columns 'col1' to 'col2' (inclusive)


# Using .iloc
print("\nUsing .iloc:")
print(df.iloc[0]) # Access row at index 0
print(df.iloc[[0, 2]]) # Access rows at indices 0 and 2
print(df.iloc[0, 0])  # Access value at row 0, column 0
print(df.iloc[0:3, 0:2]) # Access rows 0 to 2, columns 0 to 1 (exclusive of 3 and 2)
# Out:
# Using .loc:
# col1    1
# col2    6
# Name: A, dtype: int64
#    col1  col2
# A     1     6
# C     3     8
# 1
#    col1  col2
# A     1     6
# B     2     7
# C     3     8
#
# Using .iloc:
# col1    1
# col2    6
# Name: A, dtype: int64
#    col1  col2
# A     1     6
# C     3     8
# 1
#    col1  col2
# A     1     6
# B     2     7
# C     3     8

# %% [markdown]
# # Read dataset

# %%
df = pd.read_excel('/content/spotify_dataset.xlsx')
df.head()
# Out:
#                                     title          artist top genre  \
# 0                                 Flowers     Miley Cyrus       pop
# 1                       Cupid - Twin Ver.     FIFTY FIFTY     other
# 2                                    BESO         ROSALÍA       pop
# 3                      Boy's a liar Pt. 2  PinkPantheress     other
# 4  Creepin' (with The Weeknd & 21 Savage)    Metro Boomin     other
#
#   genre simplified       year  bpm  energy  danceability   dB  liveness  \
# 0              pop 2023-01-01  118      68             71  -4         3
# 1              pop 2023-01-01  120      59             78  -8        35
# 2              pop 2023-01-01   95      64             77  -7        17
# 3            other 2023-01-01  133      81             70  -8        25
# 4              rap 2022-01-01   98      62             72  -6         8
#
#    valence  duration  acousticness  speechiness   popularity
# 0       65       200             6             7          98
# ...

# %%
#select 1 or multiple columns

#select 1 column
selecting_one_column=df['dB']

# select multiple columns
selecting_columns=df[['title','top genre']]


selecting_columns
selecting_one_column
# Out:
# 0       -4
# 1       -8
# 2       -7
# 3       -8
# 4       -6
#         ..
# 2380    -6
# 2381    -4
# 2382    -7
# 2383    -6
# 2384   -10
# Name: dB, Length: 2385, dtype: int64

# %% [markdown]
# # iloc[idex_rows , index_column]

# %%
# select first row with all column   using index
df.iloc[0,:]
df.iloc[0]
# Out:
# title                           Flowers
# artist                      Miley Cyrus
# top genre                           pop
# genre simplified                    pop
# year                2023-01-01 00:00:00
# bpm                                 118
# energy                               68
# danceability                         71
# dB                                   -4
# liveness                              3
# valence                              65
# duration                            200
# acousticness                          6
# speechiness                           7
# popularity                           98
# Name: 0, dtype: object

# %%
#select the frist column
df.iloc[:,0]
# Out:
# 0                                      Flowers
# 1                            Cupid - Twin Ver.
# 2                                         BESO
# 3                           Boy's a liar Pt. 2
# 4       Creepin' (with The Weeknd & 21 Savage)
#                          ...
# 2380                                Southbound
# 2381       Dance with Somebody - Radio Version
# 2382                                      Flow
# 2383                        Scared of the Dark
# 2384                                     Sorry
# Name: title, Length: 2385, dtype: object

# %%
# select first 3 rows with all columns
df.iloc[0:3,:]
# Out:
#                title       artist top genre genre simplified       year  bpm  \
# 0            Flowers  Miley Cyrus       pop              pop 2023-01-01  118
# 1  Cupid - Twin Ver.  FIFTY FIFTY     other              pop 2023-01-01  120
# 2               BESO      ROSALÍA       pop              pop 2023-01-01   95
#
#    energy  danceability   dB  liveness  valence  duration  acousticness  \
# 0      68             71  -4         3       65       200             6
# 1      59             78  -8        35       73       174            44
# 2      64             77  -7        17       53       195            74
#
#    speechiness   popularity
# 0             7          98
# 1             3          97
# 2            14          96

# %%
# select last column with first 5 rows
df.iloc[0:5,-1]
# Out:
# 0    98
# 1    97
# 2    96
# 3    96
# 4    96
# Name: popularity, dtype: int64

# %%
#Select last 10 rows
df.iloc[-10:,:]
# Out:
#                                     title               artist    top genre  \
# 2375                           NOT AFRAID               Kodiro        other
# 2376           Pop Ya Collar - Radio Edit                Usher  atl hip hop
# 2377                        Lead You Afar    Jordan Cabo Smith        other
# 2378                               Katara        Thimo Konings        other
# 2379                           Como Saber          Marta Delas        other
# 2380                           Southbound           Beach Blvd        other
# 2381  Dance with Somebody - Radio Version           Mando Diao        other
# 2382                                 Flow      Desire Machines        other
# 2383                   Scared of the Dark  Everything Brighter          pop
# 2384                                Sorry                LEADR        other
#
#      genre simplified       year  bpm  energy  danceability   dB  liveness  \
# ...

# %%
#fancy indexing select specific rows with specific columns
df.iloc[[1,10,20],[1,2,3]]
#select rows 10 , 20 ,30  with all columns
df.iloc[[10,20,30],:]
# Out:
#                                 title        artist  top genre  \
# 10                    I'm Good (Blue)  David Guetta   big room
# 20                    Me Porto Bonito     Bad Bunny  reggaeton
# 30  All Of The Girls You Loved Before  Taylor Swift        pop
#
#    genre simplified       year  bpm  energy  danceability   dB  liveness  \
# 10            other 2022-01-01  128      97             56  -4        37
# 20        reggaeton 2022-01-01   92      71             91  -5         9
# 30              pop 2019-01-01   96      47             72 -10        13
#
#     valence  duration  acousticness  speechiness   popularity
# 10       30       175             0             3          94
# 20       43       179             9             8          92
# 30       40       221            71             4          90

# %%
''' selecting specific columns 

----------------------------1nd method---------------------------- 
new_data =old_data[['col1','col2',.....]]



----------------------------2nd method  (select all rows with specific idex columns )----------------------------
new_data = old_data.iloc[:,[Index_column]]

'''

# %% [markdown]
# # Loc[row , column_name]

# %%
#select the first value in column 'title
df.loc[0,'title']
# Out:
# 'Flowers'

# %%
#select all rows with column ['title' and 'year]
df.loc[:,['title','year']]
# Out:
#                                        title       year
# 0                                    Flowers 2023-01-01
# 1                          Cupid - Twin Ver. 2023-01-01
# 2                                       BESO 2023-01-01
# 3                         Boy's a liar Pt. 2 2023-01-01
# 4     Creepin' (with The Weeknd & 21 Savage) 2022-01-01
# ...                                      ...        ...
# 2380                              Southbound 2023-01-01
# 2381     Dance with Somebody - Radio Version 2009-01-01
# 2382                                    Flow 2022-01-01
# 2383                      Scared of the Dark 2023-01-01
# 2384                                   Sorry 2023-01-01
#
# [2385 rows x 2 columns]

# %%
#select the last 2 rows and  3 columns using loc
df.loc[:,['popularity','title','duration']]
# Out:
#       popularity                                   title  duration
# 0             98                                 Flowers       200
# 1             97                       Cupid - Twin Ver.       174
# 2             96                                    BESO       195
# 3             96                      Boy's a liar Pt. 2       131
# 4             96  Creepin' (with The Weeknd & 21 Savage)       222
# ...          ...                                     ...       ...
# 2380          21                              Southbound       228
# 2381          16     Dance with Somebody - Radio Version       241
# 2382          15                                    Flow       255
# 2383          11                      Scared of the Dark       179
# 2384           5                                   Sorry       174
#
# [2385 rows x 3 columns]

# %%
# set data index
df.set_index('title',inplace=False)
# Out:
#                                                      artist top genre  \
# title
# Flowers                                         Miley Cyrus       pop
# Cupid - Twin Ver.                               FIFTY FIFTY     other
# BESO                                                ROSALÍA       pop
# Boy's a liar Pt. 2                           PinkPantheress     other
# Creepin' (with The Weeknd & 21 Savage)         Metro Boomin     other
# ...                                                     ...       ...
# Southbound                                       Beach Blvd     other
# Dance with Somebody - Radio Version              Mando Diao     other
# Flow                                        Desire Machines     other
# Scared of the Dark                      Everything Brighter       pop
# Sorry                                                 LEADR     other
#
#                                        genre simplified       year  bpm  \
# title
# ...

# %% [markdown]
# # Conditional Selection & Assigning data

# %%
df.head()
# Out:
#                                     title          artist top genre  \
# 0                                 Flowers     Miley Cyrus       pop
# 1                       Cupid - Twin Ver.     FIFTY FIFTY     other
# 2                                    BESO         ROSALÍA       pop
# 3                      Boy's a liar Pt. 2  PinkPantheress     other
# 4  Creepin' (with The Weeknd & 21 Savage)    Metro Boomin     other
#
#   genre simplified       year  bpm  energy  danceability   dB  liveness  \
# 0              pop 2023-01-01  118      68             71  -4         3
# 1              pop 2023-01-01  120      59             78  -8        35
# 2              pop 2023-01-01   95      64             77  -7        17
# 3            other 2023-01-01  133      81             70  -8        25
# 4              rap 2022-01-01   98      62             72  -6         8
#
#    valence  duration  acousticness  speechiness   popularity
# 0       65       200             6             7          98
# ...

# %%
df['title']== 'Flowers'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2380    False
# 2381    False
# 2382    False
# 2383    False
# 2384    False
# Name: title, Length: 2385, dtype: bool

# %%
df[df['title']== 'Flowers']
# Out:
#      title       artist top genre genre simplified       year  bpm  energy  \
# 0  Flowers  Miley Cyrus       pop              pop 2023-01-01  118      68
#
#    danceability   dB  liveness  valence  duration  acousticness  speechiness   \
# 0             71  -4         3       65       200             6             7
#
#    popularity
# 0          98

# %%
filtered_df = df[(df['year'] < '2023-01-01') & (df['year'] >= '2022-01-01')]
filtered_df
# Out:
#                                                   title               artist  \
# 4                Creepin' (with The Weeknd & 21 Savage)         Metro Boomin
# 7                         Calm Down (with Selena Gomez)                 Rema
# 8                                             Anti-Hero         Taylor Swift
# 9                                          Here With Me                 d4vd
# 10                                      I'm Good (Blue)         David Guetta
# 11                                            Kill Bill                  SZA
# 13                                      I Ain't Worried          OneRepublic
# 14                 Quevedo: Bzrp Music Sessions Vol. 52             Bizarrap
# 16    Until I Found You (with Em Beihold) - Em Beiho...      Stephen Sanchez
# 18                                            As It Was         Harry Styles
# 20                                      Me Porto Bonito            Bad Bunny
# ...

# %%
filter_energy=df[(df['energy'] <= 50 ) & (df['bpm'] <=100) ]
filter_energy
# Out:
#                                   title           artist         top genre  \
# 30    All Of The Girls You Loved Before     Taylor Swift               pop
# 33                               Efecto        Bad Bunny         reggaeton
# 41                              Perfect       Ed Sheeran               pop
# 53                        Lavender Haze     Taylor Swift               pop
# 54                  Never Felt So Alone         Labrinth             other
# ...                                 ...              ...               ...
# 2272                               Love  Musiq Soulchild  contemporary r&b
# 2273                        Magic Stick         Lil' Kim         dance pop
# 2320                      Kill Me Quick      André Aires               pop
# 2322                        Slow Motion       Trey Songz         dance pop
# 2344                       Up The Score       Trill Ryan             other
#
# ...

# %%
filter_energy1 = filter_energy.sort_values(by='bpm', ascending=False)
filter_energy1
# Out:
#                                        title           artist    top genre  \
# 1809  U and Dat (feat. T. Pain & Kandi Girl)             E-40        other
# 2017               Music (feat. Marvin Gaye)     Erick Sermon        other
# 1503                            Naughty Girl          Beyoncé          pop
# 659                                   Me & U           Cassie    dance pop
# 1163                              I'm Sprung           T-Pain    dance pop
# ...                                      ...              ...          ...
# 1413                             It's A Vibe         2 Chainz  atl hip hop
# 1313                 Arcade (feat. FLETCHER)  Duncan Laurence        other
# 1347                        Lost Without You    Freya Ridings        other
# 1580                         Ordinary People      John Legend     neo soul
# 536                                  changes     XXXTENTACION        other
#
# ...

# %%
filter_energy = filter_energy . sort_values(by='year', ascending=False)
filter_energy
# Out:
#                           title           artist         top genre  \
# 2344               Up The Score       Trill Ryan             other
# 2320              Kill Me Quick      André Aires               pop
# 54          Never Felt So Alone         Labrinth             other
# 53                Lavender Haze     Taylor Swift               pop
# 33                       Efecto        Bad Bunny         reggaeton
# ...                         ...              ...               ...
# 2185            A Woman's Worth      Alicia Keys          neo soul
# 2017  Music (feat. Marvin Gaye)     Erick Sermon             other
# 2272                       Love  Musiq Soulchild  contemporary r&b
# 1941           Get It On Tonite   Montell Jordan  contemporary r&b
# 2246                   Hot Boyz    Missy Elliott         dance pop
#
#      genre simplified       year  bpm  energy  danceability   dB  liveness  \
# 2344              rap 2023-01-01   97      31             83 -10         9
# ...

# %%
filter_energy = filter_energy[filter_energy['top genre'] == 'pop'].sort_values(by=['year' ,'energy'])
filter_energy
# Out:
#                                           title           artist top genre  \
# 1787                           Me, Myself and I          Beyoncé       pop
# 1503                               Naughty Girl          Beyoncé       pop
# 1315                 Baby Boy (feat. Sean Paul)          Beyoncé       pop
# 857                                  The A Team       Ed Sheeran       pop
# 1012                              Jar of Hearts  Christina Perri       pop
# 1777                   I Knew You Were Trouble.     Taylor Swift       pop
# 475                    I Knew You Were Trouble.     Taylor Swift       pop
# 171                                Stay With Me        Sam Smith       pop
# 173                           Thinking out Loud       Ed Sheeran       pop
# 80                         I'm Not The Only One        Sam Smith       pop
# 140                        Too Good At Goodbyes        Sam Smith       pop
# ...

# %%
print(filter_energy.shape)
# Out:
# (21, 15)

# %%
def complex_condition(df):
    # Conditions with multiple criteria and logical combinations
    condition1 = (df['year'] < '2023-01-01') & (df['year'] >= '2022-01-01')
    condition2 = (df['energy'] <= 50) & (df['bpm'] <= 100)
    condition3 = (df['popularity'] > 70) | (df['danceability '] > 0.8)
    condition4 = df['top genre'].isin(['pop', 'rock', 'hip hop'])
    condition5 = df['dB'] > -5

    # Apply conditions to the dataframe with a complex combination
    complex_filter = (condition1 | condition2) & (condition3 & condition4) & condition5

    #Additional random conditions
    condition6 = np.random.randint(0, 2, size=len(df.index)).astype(bool)
    complex_filter = complex_filter | condition6

    return df[complex_filter]

# Example use (replace with your actual DataFrame):
filtered_df_ = complex_condition(df)
filtered_df_
# Out:
#                                     title             artist  \
# 1                       Cupid - Twin Ver.        FIFTY FIFTY
# 7           Calm Down (with Selena Gomez)               Rema
# 9                            Here With Me               d4vd
# 10                        I'm Good (Blue)       David Guetta
# 12                    Die For You - Remix         The Weeknd
# ...                                   ...                ...
# 2375                           NOT AFRAID             Kodiro
# 2377                        Lead You Afar  Jordan Cabo Smith
# 2378                               Katara      Thimo Konings
# 2381  Dance with Somebody - Radio Version         Mando Diao
# 2382                                 Flow    Desire Machines
#
#                       top genre genre simplified       year  bpm  energy  \
# 1                         other              pop 2023-01-01  120      59
# 7                         other            other 2022-01-01  107      81
# ...

# %%
df.isnull().sum()
# Out:
# title               0
# artist              0
# top genre           0
# genre simplified    0
# year                0
# bpm                 0
# energy              0
# danceability        0
# dB                  0
# liveness            0
# valence             0
# duration            0
# acousticness        0
# speechiness         0
# popularity          0
# dtype: int64

# %%
df_pop=df[df['top genre'].isin(['pop'])]

# %%
df_pop.shape
# Out:
# (250, 15)

# %% [markdown]
# # Assigning New data
#
# - first copy dataset
# - then modifying as u want at copy dataset

# %%
# Assigning new data without modifying the original DataFrame
new_df = df.copy()  # Create a copy to avoid modifying the original
new_df['new_column'] = 'new_value'

# %%
new_df.head() # copying dataset
# Out:
#                                     title          artist top genre  \
# 0                                 Flowers     Miley Cyrus       pop
# 1                       Cupid - Twin Ver.     FIFTY FIFTY     other
# 2                                    BESO         ROSALÍA       pop
# 3                      Boy's a liar Pt. 2  PinkPantheress     other
# 4  Creepin' (with The Weeknd & 21 Savage)    Metro Boomin     other
#
#   genre simplified       year  bpm  energy  danceability   dB  liveness  \
# 0              pop 2023-01-01  118      68             71  -4         3
# 1              pop 2023-01-01  120      59             78  -8        35
# 2              pop 2023-01-01   95      64             77  -7        17
# 3            other 2023-01-01  133      81             70  -8        25
# 4              rap 2022-01-01   98      62             72  -6         8
#
#    valence  duration  acousticness  speechiness   popularity new_column
# ...

# %%
df.head() # Original df is unchanged
# Out:
#                                     title          artist top genre  \
# 0                                 Flowers     Miley Cyrus       pop
# 1                       Cupid - Twin Ver.     FIFTY FIFTY     other
# 2                                    BESO         ROSALÍA       pop
# 3                      Boy's a liar Pt. 2  PinkPantheress     other
# 4  Creepin' (with The Weeknd & 21 Savage)    Metro Boomin     other
#
#   genre simplified       year  bpm  energy  danceability   dB  liveness  \
# 0              pop 2023-01-01  118      68             71  -4         3
# 1              pop 2023-01-01  120      59             78  -8        35
# 2              pop 2023-01-01   95      64             77  -7        17
# 3            other 2023-01-01  133      81             70  -8        25
# 4              rap 2022-01-01   98      62             72  -6         8
#
#    valence  duration  acousticness  speechiness   popularity
# 0       65       200             6             7          98
# ...

# %%
# prompt: how to add new columns  at our dataset ?

# Adding a new column with a constant value
df['new_column'] = 'new_value'

# Adding a new column based on an existing column
df['double_popularity'] = df['popularity'] * 2

# Adding a new column based on a condition
df['high_popularity'] = df['popularity'] > 80

# Adding a new column using a function
def categorize_popularity(popularity):
    if popularity > 90:
        return 'very high'
    elif popularity > 70:
        return 'high'
    else:
        return 'low'

df['popularity_category'] = df['popularity'].apply(categorize_popularity)

# Adding a new column with random numbers
df['random_number'] = np.random.rand(len(df))

# %%
#adding new columns
df['new_col']=df['energy']+df['bpm']
df
# Out:
#                                        title               artist top genre  \
# 0                                    Flowers          Miley Cyrus       pop
# 1                          Cupid - Twin Ver.          FIFTY FIFTY     other
# 2                                       BESO              ROSALÍA       pop
# 3                         Boy's a liar Pt. 2       PinkPantheress     other
# 4     Creepin' (with The Weeknd & 21 Savage)         Metro Boomin     other
# ...                                      ...                  ...       ...
# 2380                              Southbound           Beach Blvd     other
# 2381     Dance with Somebody - Radio Version           Mando Diao     other
# 2382                                    Flow      Desire Machines     other
# 2383                      Scared of the Dark  Everything Brighter       pop
# 2384                                   Sorry                LEADR     other
#
# ...

# %% [markdown]
# # Replacing Values
#
# replace(Old,New)

# %%
# Replace Function with 2 method 

# df["education"] = df_campaign["education"].str.replace('.', '_')
df["education"] = df["education"].str.replace(r'\.', '_', regex=True)

# Convert 'unknown' to NaN
df["education"] = df["education"].replace('unknown', np.nan)

# %% [markdown]
# # Mappingg value with another value
#
# - map(function, iterables)
#
# - note function can be lambda

# %%
#1nd method 
df['column_name']=df['column_name'].map({"no":0 , "yes":1})

# %%
#Convert "campaign_outcome" to binary values using .map() method
df['campaign_outcome'] = df['campaign_outcome'].map({'success': 1, 'failure': 0})

# Alternatively, using .apply() method
df['campaign_outcome'] = df['campaign_outcome'].apply(lambda x: 1 if x == 'success' else 0)

# Another alternative using .replace() method
df['campaign_outcome'] = df['campaign_outcome'].replace({'success': 1, 'failure': 0})

# %% [markdown]
# # apply() Method
#
# - The apply( ) method allows you to apply a function along one of the axis of the DataFrame
# - dataframe.apply(
#   func ,
#   axis ,
#   raw ,
#   result_type ,
#   args ,
#   kwds
#   )
#
# - axis ==> 0 , 1 , 'index' , 'columns'

# %%
# Sample DataFrame
data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# Define a function to apply
def multiply_by_two(x):
    return x * 2

# Apply the function to column 'A'
df['A_doubled'] = df['A'].apply(multiply_by_two)

# Apply a lambda function to column 'B'
df['B_squared'] = df['B'].apply(lambda x: x ** 2)

print(df)

# %% [markdown]
# # Drop Columns
#
# Which Method Should You Use?
#
# ✅ .drop() → Most common and flexible
#
# ✅ .pop() → If you need to keep the removed column
#
# ✅ .filter() → If you want to drop columns with specific keywords
#
# ✅ .dropna() → If dealing with missing values

# %%
#1nd method 
df.drop('column_name',inplace=True)


#2nd method 
df=df.drop('column_name')


#3nd method but multi columns 
df.drop(['col1','col2'],inplace=True)


#4nd method by index columns
df = df.drop(df.columns[[0, 2]], axis=1)  # Drops first and third columns

# %% [markdown]
# ### **Which Method Should You Use to Drop Rows?**
#
# | **Method**               | **Use Case**                                      |
# | ------------------------ | ------------------------------------------------- |
# | `df.drop(index)`         | Remove rows by **specific index**                 |
# | `df[df['col'] != value]` | Drop rows where a **column has a certain value**  |
# | `df.dropna()`            | Remove rows that **contain NaN (missing) values** |
# | `df.drop_duplicates()`   | Eliminate **duplicate rows**                      |
# | `df.iloc[]`              | Drop the **first or last N rows**                 |

# %% [markdown]
# # Handling Missing Values
#
# 1.  find null values `isnull` : Checks for missing values (NaN) in the Returns a DataFrame of the same shape as df with True DataFrame , if found NAN valuess
# 2.  `notnull()` == check for missing values
#
# 3.  `info()` Displays information about the DataFrame, including data types, memory usage, and presence of missing values.
#
# 4.` isna()` similar to notnull() but returns True for missing values and False for non-missing values.
#
# 5.` dropna()` = drop NaN value
#
# 6. `fillna()` Fills missing values with specific values, means, medians, min , max ,scaler and dictionary. 7.`replace()` Replaces specific values with other values
#
# 7. `drop_duplicates()  ` Removes duplicate rows based on specified columns.
#
# 8. `unique()` Finds unique values in a Series or DataFrame.

# %%
""" fillna :
         df.fillna(value=None, method=None, axis=None, inplace=False, limit=None)

value   ==> The value to replace missing values (NaN) with can be  scaler or dictionary
method  ==> Used to fill missing values using a specific strategy   Forward fill , Backward fil
axis    ==> Determines whether to fill along rows (axis=0) or columns (axis=1) , default is axis= 0
limit   ==> The maximum number of consecutive NaN values to forward fill or backward fill.




Replace :
df.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method=None)

to_replace ==> Specifies the value(s) to be replaced.  Can be a scalar, list, dictionary, or a regular expression.
regex=False ==>
"""
# Out:
# ' fillna :\n         df.fillna(value=None, method=None, axis=None, inplace=False, limit=None)\n\nvalue   ==> The value to replace missing values (NaN) with can be  scaler or dictionary\nmethod  ==> Used to fill missing values using a specific strategy   Forward fill , Backward fil\naxis    ==> Determines whether to fill along rows (axis=0) or columns (axis=1) , default is axis= 0\nlimit   ==> The maximum number of consecutive NaN values to forward fill or backward fill.\n\n\n\n\nReplace :\ndf.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method=None)\n\nto_replace ==> Specifies the value(s) to be replaced.  Can be a scalar, list, dictionary, or a regular expression.\nregex=False ==>\n'

# %%
# find missing values in dataset
df.isnull().sum()
# Out:
# title                  0
# artist                 0
# top genre              0
# genre simplified       0
# year                   0
# bpm                    0
# energy                 0
# danceability           0
# dB                     0
# liveness               0
# valence                0
# duration               0
# acousticness           0
# speechiness            0
# popularity             0
# new_column             0
# double_popularity      0
# high_popularity        0
# popularity_category    0
# random_number          0
# new_col                0
# dtype: int64

# %%
#to check NAN values at specific column
df.loc[df['dB'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, artist, top genre, genre simplified, year, bpm, energy, danceability , dB, liveness, valence, duration, acousticness, speechiness , popularity, new_column, double_popularity, high_popularity, popularity_category, random_number, new_col]
# Index: []
#
# [0 rows x 21 columns]

# %%
avg=(df.isnull().sum()/df.shape[0])
avg
# Out:
# title                  0.0
# artist                 0.0
# top genre              0.0
# genre simplified       0.0
# year                   0.0
# bpm                    0.0
# energy                 0.0
# danceability           0.0
# dB                     0.0
# liveness               0.0
# valence                0.0
# duration               0.0
# acousticness           0.0
# speechiness            0.0
# popularity             0.0
# new_column             0.0
# double_popularity      0.0
# high_popularity        0.0
# popularity_category    0.0
# random_number          0.0
# new_col                0.0
# dtype: float64

# %%
# drop rows with NAN value
#this function will remove all row if found 1 value has NAN
df.dropna(inplace=False)
# Out:
#                                        title               artist top genre  \
# 0                                    Flowers          Miley Cyrus       pop
# 1                          Cupid - Twin Ver.          FIFTY FIFTY     other
# 2                                       BESO              ROSALÍA       pop
# 3                         Boy's a liar Pt. 2       PinkPantheress     other
# 4     Creepin' (with The Weeknd & 21 Savage)         Metro Boomin     other
# ...                                      ...                  ...       ...
# 2380                              Southbound           Beach Blvd     other
# 2381     Dance with Somebody - Radio Version           Mando Diao     other
# 2382                                    Flow      Desire Machines     other
# 2383                      Scared of the Dark  Everything Brighter       pop
# 2384                                   Sorry                LEADR     other
#
# ...

# %%
#drop columns  with values NAN
df.dropna(axis=1 , inplace = False)# == df.dropna(axis='columns' , inplace = False)
# Out:
#                                        title               artist top genre  \
# 0                                    Flowers          Miley Cyrus       pop
# 1                          Cupid - Twin Ver.          FIFTY FIFTY     other
# 2                                       BESO              ROSALÍA       pop
# 3                         Boy's a liar Pt. 2       PinkPantheress     other
# 4     Creepin' (with The Weeknd & 21 Savage)         Metro Boomin     other
# ...                                      ...                  ...       ...
# 2380                              Southbound           Beach Blvd     other
# 2381     Dance with Somebody - Radio Version           Mando Diao     other
# 2382                                    Flow      Desire Machines     other
# 2383                      Scared of the Dark  Everything Brighter       pop
# 2384                                   Sorry                LEADR     other
#
# ...

# %%
# TO remove missing values at specific  columns
df.dropna(subset=['dB'],inplace=False)
# Out:
#                                        title               artist top genre  \
# 0                                    Flowers          Miley Cyrus       pop
# 1                          Cupid - Twin Ver.          FIFTY FIFTY     other
# 2                                       BESO              ROSALÍA       pop
# 3                         Boy's a liar Pt. 2       PinkPantheress     other
# 4     Creepin' (with The Weeknd & 21 Savage)         Metro Boomin     other
# ...                                      ...                  ...       ...
# 2380                              Southbound           Beach Blvd     other
# 2381     Dance with Somebody - Radio Version           Mando Diao     other
# 2382                                    Flow      Desire Machines     other
# 2383                      Scared of the Dark  Everything Brighter       pop
# 2384                                   Sorry                LEADR     other
#
# ...

# %%
# the counts of duplicated values
df.duplicated().sum()
# drop duplicates value s
df.drop_duplicates(inplace=False)
# Out:
#                                        title               artist top genre  \
# 0                                    Flowers          Miley Cyrus       pop
# 1                          Cupid - Twin Ver.          FIFTY FIFTY     other
# 2                                       BESO              ROSALÍA       pop
# 3                         Boy's a liar Pt. 2       PinkPantheress     other
# 4     Creepin' (with The Weeknd & 21 Savage)         Metro Boomin     other
# ...                                      ...                  ...       ...
# 2380                              Southbound           Beach Blvd     other
# 2381     Dance with Somebody - Radio Version           Mando Diao     other
# 2382                                    Flow      Desire Machines     other
# 2383                      Scared of the Dark  Everything Brighter       pop
# 2384                                   Sorry                LEADR     other
#
# ...

# %% [markdown]
# # Combine two dataframe
#
# - Concatenate ()
#
#   - merging() combine based on specified columns
#
#   - Joining() combine DataFrames based on their indexes.
#
#   - Appending
#
#   - Updating

# %% [markdown]
# ### Concatenate ()
#
# - concat multi rows

# %%
#Concatenate ()
concate_df= pd.concat([df1,df2], axis = 0 ,ignore_index=True)
concate_df
# Out:
#             item_category_name  item_category_id  \
# 0      PC - Гарнитуры/Наушники                 0
# 1             Аксессуары - PS2                 1
# 2             Аксессуары - PS3                 2
# 3             Аксессуары - PS4                 3
# 4             Аксессуары - PSP                 4
# ...                        ...               ...
# 22249                      NaN                31
# 22250                      NaN                54
# 22251                      NaN                49
# 22252                      NaN                62
# 22253                      NaN                69
#
#                                                item_name  item_id
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                                                    NaN      NaN
# 3                                                    NaN      NaN
# ...

# %% [markdown]
# ### Merge()
#
# - dataframe.merge( right,
#   how,
#   on,
#   left_on,
#   right_on,
#   left_index,
#   right_index,
#   sort,
#   suffixes,
#   copy,
#   indicator,
#   validate
#   )
#
# - merge columns as JOIN in SQL

# %%
#merge()
''' how ==> [inner , outer , left , right  ]
    ON ==> if  Key name  is same  
    left_on , right_on ==> if Key name differ
'''
merge_df=pd.merge(df1,df2,how='inner',on='item_category_id')


#######################################################################
# if both key with differ names
merge_df=df1.merge(df2,how='inner',left_on='df1 key',right_on='df2 key')
# Out:
#             item_category_name  item_category_id  \
# 0      PC - Гарнитуры/Наушники                 0
# 1      PC - Гарнитуры/Наушники                 0
# 2      PC - Гарнитуры/Наушники                 0
# 3      PC - Гарнитуры/Наушники                 0
# 4             Аксессуары - PS2                 1
# ...                        ...               ...
# 22165         Элементы питания                83
# 22166         Элементы питания                83
# 22167         Элементы питания                83
# 22168         Элементы питания                83
# 22169         Элементы питания                83
#
#                                                item_name  item_id
# 0      PC: Гарнитура HyperX Cloud Core игровая стерео...     5441
# 1                            Наушники PHILIPS SBC HC8680    16255
# 2                                 Наушники RITMIX RH-120    16256
# 3                           Наушники RITMIX RH-124 Black    16257
# ...

# %%
merge__df=pd.merge(df1,df2 , how = 'left', on = 'item_category_id')
merge__df
# Out:
#             item_category_name  item_category_id  \
# 0      PC - Гарнитуры/Наушники                 0
# 1      PC - Гарнитуры/Наушники                 0
# 2      PC - Гарнитуры/Наушники                 0
# 3      PC - Гарнитуры/Наушники                 0
# 4             Аксессуары - PS2                 1
# ...                        ...               ...
# 22165         Элементы питания                83
# 22166         Элементы питания                83
# 22167         Элементы питания                83
# 22168         Элементы питания                83
# 22169         Элементы питания                83
#
#                                                item_name  item_id
# 0      PC: Гарнитура HyperX Cloud Core игровая стерео...     5441
# 1                            Наушники PHILIPS SBC HC8680    16255
# 2                                 Наушники RITMIX RH-120    16256
# 3                           Наушники RITMIX RH-124 Black    16257
# ...

# %%
merge__df=pd.merge( df1,df2 , how = 'left', on = 'item_category_id' )
merge__df
# Out:
#             item_category_name  item_category_id  \
# 0      PC - Гарнитуры/Наушники                 0
# 1      PC - Гарнитуры/Наушники                 0
# 2      PC - Гарнитуры/Наушники                 0
# 3      PC - Гарнитуры/Наушники                 0
# 4             Аксессуары - PS2                 1
# ...                        ...               ...
# 22165         Элементы питания                83
# 22166         Элементы питания                83
# 22167         Элементы питания                83
# 22168         Элементы питания                83
# 22169         Элементы питания                83
#
#                                                item_name  item_id
# 0      PC: Гарнитура HyperX Cloud Core игровая стерео...     5441
# 1                            Наушники PHILIPS SBC HC8680    16255
# 2                                 Наушники RITMIX RH-120    16256
# 3                           Наушники RITMIX RH-124 Black    16257
# ...

# %% [markdown]
# ### join ()

# %%
'''
lsuffix
rsuffix
يُستخدمان لحل تعارض أسماء الأعمدة عند الدمج.
'''
df1.join(df2, lsuffix='_left', rsuffix='_right')
# Out:
#            item_category_name  item_category_id_left  \
# 0     PC - Гарнитуры/Наушники                      0
# 1            Аксессуары - PS2                      1
# 2            Аксессуары - PS3                      2
# 3            Аксессуары - PS4                      3
# 4            Аксессуары - PSP                      4
# ..                        ...                    ...
# 79                  Служебные                     79
# 80         Служебные - Билеты                     80
# 81    Чистые носители (шпиль)                     81
# 82  Чистые носители (штучные)                     82
# 83           Элементы питания                     83
#
#                                             item_name  item_id  \
# 0           ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1   !ABBYY FineReader 12 Professional Edition Full...        1
# 2       ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3     ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# ...

# %% [markdown]
# # Aggregations and Groupby
#
# - Groupby() is a powerful function in pandas that allows you to group data based on a single column or more
#
# - You can apply many operations to a groupby object, including aggregation functions like sum(), mean(), and count(), as well as lambda function and other custom functions using apply().
#
# ## groupby
#
# 1.  agg
# 2.  filter
# 3.  transform
# 4.  apply

# %%
# Sample DataFrame (replace with your actual data)
data = {'Category': ['A', 'A', 'B', 'B', 'C', 'C'],
        'Value1': [10, 15, 20, 25, 30, 35],
        'Value2': [5, 10, 15, 20, 25, 30]}
df = pd.DataFrame(data)
df
# Out:
#   Category  Value1  Value2
# 0        A      10       5
# 1        A      15      10
# 2        B      20      15
# 3        B      25      20
# 4        C      30      25
# 5        C      35      30

# %%
# 1. Aggregation (agg)
# aggfunc: can be  function, list of functions, dict, default numpy.mean
# Calculate the sum and mean of 'Value1' and 'Value2' for each category
aggregated_df = df.groupby('Category').agg({'Value1': ['sum', 'mean'], 'Value2': ['sum', 'mean']})
print("Aggregated DataFrame:\n", aggregated_df)
# Out:
# Aggregated DataFrame:
#           Value1       Value2
#             sum  mean    sum  mean
# Category
# A            25  12.5     15   7.5
# B            45  22.5     35  17.5
# C            65  32.5     55  27.5

# %%
# 2. Filtering (filter)
# Keep only categories where the mean of 'Value1' is greater than 20
filtered_df = df.groupby('Category').filter(lambda x: x['Value1'].mean() > 20)
print("\nFiltered DataFrame:\n", filtered_df)
# Out:
# Filtered DataFrame:
#    Category  Value1  Value2
# 2        B      20      15
# 3        B      25      20
# 4        C      30      25
# 5        C      35      30

# %%
# 3. Transformation (transform)
# Standardize 'Value1' within each category (subtract mean, divide by standard deviation)
#Returns A DataFrame of the same shape as the input with transformed values.

df['Value1_standardized'] = df.groupby('Category')['Value1'].transform(lambda x: (x - x.mean()) / x.std())
print("\nDataFrame with Transformed Column:\n", df)
# Out:
# DataFrame with Transformed Column:
#    Category  Value1  Value2  Value1_standardized
# 0        A      10       5            -0.707107
# 1        A      15      10             0.707107
# 2        B      20      15            -0.707107
# 3        B      25      20             0.707107
# 4        C      30      25            -0.707107
# 5        C      35      30             0.707107

# %%
# 4. Apply (apply)
# Create a new column 'Value_Ratio' by dividing 'Value1' by the sum of 'Value1' for each category.
def calculate_ratio(group):
    group['Value_Ratio'] = group['Value1'] / group['Value1'].sum()
    return group

applied_df = df.groupby('Category').apply(calculate_ratio)
print("\nDataFrame with Applied Function:\n", applied_df)
# Out:
# DataFrame with Applied Function:
#             Category  Value1  Value2  Value1_standardized  Value_Ratio
# Category
# A        0        A      10       5            -0.707107     0.400000
#          1        A      15      10             0.707107     0.600000
# B        2        B      20      15            -0.707107     0.444444
#          3        B      25      20             0.707107     0.555556
# C        4        C      30      25            -0.707107     0.461538
#          5        C      35      30             0.707107     0.538462
# <ipython-input-10-18df042ed5aa>:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   applied_df = df.groupby('Category').apply(calculate_ratio)

# %%
# Example with multiple aggregate functions and custom function
def range_fn(x):
    return f"{x.min()}-{x.max()}"

grouped = df.groupby('Category').agg(
    value1_sum=('Value1','sum'),
    value1_range=('Value1',range_fn),
    value2_mean=('Value2','mean')
    )
print("\nDataFrame with multiple agg functions and custom function:\n",grouped)

# Example of using a custom function with apply
def custom_function(group):
    # Perform calculations on the group
    group['new_col'] = group['Value1'] * 2 + group['Value2']
    return group
result = df.groupby('Category').apply(custom_function)
print("\nDataFrame with custom function using apply:\n",result)
# Out:
# DataFrame with multiple agg functions and custom function:
#            value1_sum value1_range  value2_mean
# Category
# A                 25        10-15          7.5
# B                 45        20-25         17.5
# C                 65        30-35         27.5
#
# DataFrame with custom function using apply:
#             Category  Value1  Value2  Value1_standardized  new_col
# Category
# A        0        A      10       5            -0.707107       25
#          1        A      15      10             0.707107       40
# B        2        B      20      15            -0.707107       55
#          3        B      25      20             0.707107       70
# C        4        C      30      25            -0.707107       85
#          5        C      35      30             0.707107      100
# ...

# %% [markdown]
# # Pivot Table
#
# - A PivotTable is a powerful tool to calculate, summarize, and analyze data that lets you see comparisons, patterns, and trends in your data.
#
# - pandas.pivot_table(
#
#   data,
#
#   values=None,
#
#   index=None,
#
#   columns=None,
#
#   aggfunc=’mean’,
#
#   fill_value=None,
#
#   margins=False,
#
#   dropna=True,
#
#   margins_name=’All’
#
#   )

# %%
# prompt: pivot table explain

# Import pandas library
import pandas as pd

# Sample DataFrame (replace with your actual data)
data = {'Category': ['A', 'A', 'B', 'B', 'C', 'C'],
        'Subcategory': ['X', 'Y', 'X', 'Y', 'X', 'Y'],
        'Value1': [10, 15, 20, 25, 30, 35],
        'Value2': [5, 10, 15, 20, 25, 30]}
df = pd.DataFrame(data)

# Basic pivot table: Calculate the sum of 'Value1' for each 'Category' and 'Subcategory'
pivot_table = pd.pivot_table(df, values='Value1', index='Category', columns='Subcategory', aggfunc='sum')
print("Basic Pivot Table:\n", pivot_table)

# Pivot table with multiple aggregate functions: Calculate the sum and mean of 'Value1'
pivot_table_multiple_agg = pd.pivot_table(df, values='Value1', index='Category', columns='Subcategory', aggfunc=['sum', 'mean'])
print("\nPivot Table with Multiple Aggregate Functions:\n", pivot_table_multiple_agg)

# Pivot table with margins: Include row and column totals
pivot_table_margins = pd.pivot_table(df, values='Value1', index='Category', columns='Subcategory', aggfunc='sum', margins=True)
print("\nPivot Table with Margins:\n", pivot_table_margins)

# Pivot table with fill_value: Replace missing values with a specific value (e.g., 0)
pivot_table_fill_value = pd.pivot_table(df, values='Value1', index='Category', columns='Subcategory', aggfunc='sum', fill_value=0)
print("\nPivot Table with Fill Value:\n", pivot_table_fill_value)
# Out:
# Basic Pivot Table:
#  Subcategory   X   Y
# Category
# A            10  15
# B            20  25
# C            30  35
#
# Pivot Table with Multiple Aggregate Functions:
#              sum      mean
# Subcategory   X   Y     X     Y
# Category
# A            10  15  10.0  15.0
# B            20  25  20.0  25.0
# C            30  35  30.0  35.0
#
# Pivot Table with Margins:
#  Subcategory   X   Y  All
# Category
# A            10  15   25
# B            20  25   45
# C            30  35   65
# All          60  75  135
#
# Pivot Table with Fill Value:
#  Subcategory   X   Y
# Category
# A            10  15
# B            20  25
# C            30  35

# %% [markdown]
# #

# %% [markdown]
# # Date Time & Time Series

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import datetime 

# 1st methed to convert string to datetime
df['data_column'] = pd.to_datetime(df['data_column'])

# 2sd method if python can't detect date so to convert string to datetime
df['data_column'] = pd.to_datetime(df['data_column'], format='%Y-%m-%d')

# %%
import pandas as pd

# Sample DataFrame
data = {'Date': ['2015-04-01 16:00:00', '2015-04-02 16:00:00', 
                 '2015-04-06 16:00:00', '2015-04-07 16:00:00', 
                 '2015-04-08 16:00:00']}
df = pd.DataFrame(data)

# Convert to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Extract only the date
df['Date'] = df['Date'].dt.date

print(df)
# Out:
#          Date
# 0  2015-04-01
# 1  2015-04-02
# 2  2015-04-06
# 3  2015-04-07
# 4  2015-04-08

# %%
# to make Date column as index 
''' 
why we need to make Date as index ? 
    - to make it easy to access the data by date and make it uniqe without duplicate
    - to make it easy to plot the data by date
'''
df.set_index('Date', inplace=True)

# %%
# to get the information  by specific date 
df.loc['2015-04-01']['column_name'].sum() 
df.loc['2015-04-01']['column_name'].min()
df.loc['2015-04-01']['column_name'].mean()

# %%
"""
- Resample method Similar to how we can group data by category, resampling lets us group data into different time intervals.
- This is valuable for both data cleaning and in-depth time series analysis
- Resampling is a powerful tool for time series data, allowing us to aggregate data over different time intervals.
-  علشان اقدر احسب البيانات باليوم او الشهر او السنة بستخدام الدالة دي

-Most common time series frequencies are: 
                    'D' (daily),
                    'W' (weekly),
                    'M' (monthly),
                    'Q' (quarterly),
                    'A' (annually)
"""


df.resample('D').sum() # Resample data by day and calculate the sum
df['column_name'].resample('D').mean() # Resample a specific column by day and calculate the mean

# %%
# Resample data by month and calculate sum for column1 and mean for column2
# يعني لو عاوز احسب البيانات بالشهر واجمع البيانات بالعمود الاول واحسب المتوسط بالعمود الثاني
df.resample("M").agg({'column_name1': 'sum', 'column_name2': 'mean'})

# %% [markdown]
# # After cleaning your data, you can save it in different formats using **Pandas**. Here are the most common methods:
#
# ---
#
# ### **1️⃣ Save as CSV (Most Common)**
#
# ```python
# df.to_csv("cleaned_data.csv", index=False)
# ```
#
# ✅ **Removes the index** (recommended for clean datasets).
# ✅ **Fast and widely used** format.
#
# If you **want to keep the index**, use:
#
# ```python
# df.to_csv("cleaned_data.csv", index=True)
# ```
#
# ---
#
# ### **2️⃣ Save as Excel**
#
# ```python
# df.to_excel("cleaned_data.xlsx", index=False)
# ```
#
# ✅ Best for sharing with **non-technical users**.
# ✅ Supports **multiple sheets** (using `ExcelWriter`).
#
# Example for multiple sheets:
#
# ```python
# with pd.ExcelWriter("cleaned_data.xlsx") as writer:
#     df.to_excel(writer, sheet_name="Sheet1", index=False)
# ```
#
# ---
#
# ### **3️⃣ Save as JSON**
#
# ```python
# df.to_json("cleaned_data.json", orient="records")
# ```
#
# ✅ Useful for **web applications** and APIs.
# ✅ Stores data as a list of dictionaries.
#
# ---
#
# ### **4️⃣ Save as Pickle (Fastest for Python)**
#
# ```python
# df.to_pickle("cleaned_data.pkl")
# ```
#
# ✅ **Best for large datasets** (preserves DataFrame format).
# 🚫 **Only works with Python** (not human-readable).
#
# ---
#
# ### **5️⃣ Save to a Database (SQL)**
#
# ```python
# from sqlalchemy import create_engine
#
# engine = create_engine("sqlite:///cleaned_data.db")
# df.to_sql("table_name", engine, if_exists="replace", index=False)
# ```
#
# ✅ Best for **large datasets** and **long-term storage**.
# ✅ Supports **querying with SQL**.
#
# ---
#
# ### **Which Format Should You Use?**
#
# | **Format**  | **Best For**               |
# | ----------- | -------------------------- |
# | `.csv`      | General use & easy sharing |
# | `.xlsx`     | Reports & spreadsheets     |
# | `.json`     | Web apps & APIs            |
# | `.pkl`      | Fast loading in Python     |
# | `.db` (SQL) | Large datasets & databases |

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # Zip Function
#
# - zip ()
# - To compining object

# %%
name = ['Tom', 'Nick', 'John']
age = [25, 30, 26]
compining = zip(name, age)
print(compining)
print(dict(compining))
#return object as tuple 
print(compining)
print(type(compining))
# Out:
# ...
# {'Tom': 25, 'Nick': 30, 'John': 26}
# ...
# <class 'zip'>

# %% [markdown]
# # NOtes

# %%
# Assuming 'df' is your DataFrame and 'RD' is the column of interest
# Find the year in which the maximum value of 'RD' occurred

max_rd_year = df.loc[df['RD'].idxmax(), 'year'] #idxmax() → Finds the index of the row where RD is maximum.
print(f"The year with the maximum value of RD is: {max_rd_year}")

# %%
max_rd_row = df.sort_values(by="RD", ascending=False).iloc[0]
print(max_rd_row["Year"])

# %% [markdown]
# # 3 Methods to apply calculation on columns

# %%
win_perc_preds_loop = []

# Use a loop and .itertuples() to collect each row's predicted win percentage
for row in df.itertuples():
    runs_scored = row.RS
    runs_allowed = row.RA
    win_perc_pred = predict_win_perc(runs_scored, runs_allowed)
    win_perc_preds_loop.append(win_perc_pred)

# Apply predict_win_perc to each row of the DataFrame
win_perc_preds_apply = df.apply(lambda row: predict_win_perc(row['RS'], row['RA']), axis=1)

# Calculate the win percentage predictions using NumPy arrays
win_perc_preds_np = predict_win_perc(df['RS'].values, df['RA'].values)
df['WP_preds'] = win_perc_preds_np
print(df.head())

# %% [markdown]
# # To get larger and smallest recoreds

# %%
# to get top smalles recored based on column 
print(df.nsmallest(10,['column_name']))
# to get top largerest recored based on column 
print(df.nlargest(10,['column_name']))

# %% [markdown]
# # Ensuring Data persistence

# %%
import pandas as pd 
import os 

## after Extract , Transform and Load Data 

# Check that the path exists 
file_exists = os.path.exists("df_after_loaded")
print(file_exists) 

"""
True ==> means file is exist
False ==> Means file is Not exist 
"""

# %% [markdown]
# # Python Logging Packages
#
# (a) Built-in Python Logging (logging module)
#
# (b) Logging is a means of tracking events that happen when some software runs
#
# - Standard library for logging in Python.
#
# - Supports different logging levels (DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
# - Can write logs to files, streams, or external services.

# %%
import logging

# Configure logging
logging.basicConfig(
    filename="pipeline.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

# Sample logs
logging.info("Pipeline started")
logging.warning("Data quality issue detected")
logging.error("Pipeline step failed due to missing column")

# %% [markdown]
# Output
# ![image.png](attachment:image.png)
